# %%
a = 10
b = 3.14
c = "Python"
d = True
print(a, type(a))
print(b, type(b))
print(c, type(c))
print(d, type(d))
# Out:
# 10 <class 'int'>
# 3.14 <class 'float'>
# Python <class 'str'>
# True <class 'bool'>

# %%
s = "Hello"
s += " World"
print(s)
# Out:
# Hello World

# %%
s = "Hi"
print(s + " Python")
print(s * 3)
# Out:
# Hi Python
# HiHiHi
